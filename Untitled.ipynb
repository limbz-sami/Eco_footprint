# %%
# %run ./footprint_v_biocapacity.ipynb 

eco_sort.head()
# Out:
#      Country         Region  Population (millions)   HDI GDP per Capita  \
# 0  Singapore   Asia-Pacific                   5.30  0.91     $53,122.40
# 1    Bermuda  North America                   0.06   NaN     $70,626.30
# 2   Barbados  Latin America                   0.28  0.79     $15,722.80
# 3      Aruba  Latin America                   0.10   NaN            NaN
# 4    Réunion         Africa                   0.86   NaN            NaN
#
#    Cropland Footprint  Grazing Footprint  Forest Footprint  Carbon Footprint  \
# 0                0.67               0.24              0.91              5.91
# 1                 NaN                NaN               NaN               NaN
# 2                0.56               0.24              0.14              3.28
# 3                 NaN                NaN               NaN               NaN
# 4                0.14               0.01              0.15              3.27
#
# ...
