# %%
# %matplotlib inline
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

filepath = os.path.join('Resources', 'countries.csv')
eco_csv = pd.read_csv(filepath, header=0)
eco_csv.head()
# Out:
#                Country                    Region  Population (millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#   GDP per Capita  Cropland Footprint  Grazing Footprint  Forest Footprint  \
# 0        $614.66                0.30               0.20              0.08
# 1      $4,534.37                0.78               0.22              0.25
# 2      $5,430.57                0.60               0.16              0.17
# 3      $4,665.91                0.33               0.15              0.12
# 4     $13,205.10                 NaN                NaN               NaN
#
#    Carbon Footprint  Fish Footprint  ...  Cropland  Grazing Land  Forest Land  \
# 0              0.18            0.00  ...      0.24          0.20         0.02
# 1              0.87            0.02  ...      0.55          0.21         0.29
# 2              1.14            0.01  ...      0.24          0.27         0.03
# 3              0.20            0.09  ...      0.20          1.42         0.64
# 4               NaN             NaN  ...       NaN           NaN          NaN
#
#    Fishing Water  Urban Land  Total Biocapacity  \
# 0           0.00        0.04               0.50
# 1           0.07        0.06               1.18
# 2           0.01        0.03               0.59
# 3           0.26        0.04               2.55
# 4            NaN         NaN               0.94
#
#    Biocapacity Deficit or Reserve  Earths Required  Countries Required  \
# 0                           -0.30             0.46                1.60
# 1                           -1.03             1.27                1.87
# 2                           -1.53             1.22                3.61
# 3                            1.61             0.54                0.37
# 4                           -4.44             3.11                5.70
#
#    Data Quality
# 0             6
# 1             6
# 2             5
# 3             6
# 4             2
#
# [5 rows x 21 columns]

# %%
# New dataframe with only GDP, HDI & Footprint
my_df = pd.DataFrame(eco_csv.iloc[:,[0,1,2,3,4,10,17]])
my_df['GDP per Capita'] = my_df['GDP per Capita'].str.replace('$','')
my_df['GDP per Capita'] = my_df['GDP per Capita'].str.replace(',','')
my_df['GDP per Capita'] = my_df['GDP per Capita'].astype(float)
my_df['Footprint per Mil Persons'] = my_df['Total Ecological Footprint']/my_df['Population (millions)']
my_df.dropna(how='any', inplace=True)
# my_df.count()
# my_df.dtypes
my_df.head()
# Out:
#                Country                    Region  Population (millions)   HDI  \
# 0          Afghanistan  Middle East/Central Asia                  29.82  0.46
# 1              Albania   Northern/Eastern Europe                   3.16  0.73
# 2              Algeria                    Africa                  38.48  0.73
# 3               Angola                    Africa                  20.82  0.52
# 4  Antigua and Barbuda             Latin America                   0.09  0.78
#
#    GDP per Capita  Total Ecological Footprint  Biocapacity Deficit or Reserve  \
# 0          614.66                        0.79                           -0.30
# 1         4534.37                        2.21                           -1.03
# 2         5430.57                        2.12                           -1.53
# 3         4665.91                        0.93                            1.61
# 4        13205.10                        5.38                           -4.44
#
#    Footprint per Mil Persons
# 0                   0.026492
# 1                   0.699367
# 2                   0.055094
# 3                   0.044669
# 4                  59.777778

# %%
# Scatter plot of HDI v GDP weighted by Footprint
hdi = my_df['HDI'].tolist()
gdp = my_df['GDP per Capita'].tolist()
# bdr = my_df['Biocapacity Deficit or Reserve'].tolist()
footprint = my_df['Footprint per Mil Persons'].tolist()
footprint = [dot+5 for dot in footprint]

fig, ax = plt.subplots(figsize=(9,7))
plt.scatter(hdi, gdp, s=footprint, color='indianred')
plt.title('HDI v GDP (Weighted by Eco Footprint)')
plt.xlabel('HDI')
plt.ylabel('GDP per Capita')
plt.grid()
plt.tight_layout()
plt.savefig('Images/hdi_gdp.png')
plt.show()

# %%
# Developing Countries with HDI Between 0.7 & 0.8
developing = my_df.loc[(my_df['HDI']>0.7) & (my_df['HDI']<0.8),:]
developing = developing.sort_values('Region')
developing.reset_index(inplace=True, drop=True)
developing
# Out:
#                               Country                    Region  \
# 0                             Algeria                    Africa
# 1                             Tunisia                    Africa
# 2              Libyan Arab Jamahiriya                    Africa
# 3                           Mauritius                    Africa
# 4                                Fiji              Asia-Pacific
# 5                               Tonga              Asia-Pacific
# 6                           Sri Lanka              Asia-Pacific
# 7                            Malaysia              Asia-Pacific
# 8                               China              Asia-Pacific
# 9                            Mongolia              Asia-Pacific
# 10                           Thailand              Asia-Pacific
# 11                           Bulgaria            European Union
# 12                            Romania            European Union
# 13                            Jamaica             Latin America
# 14       Saint Vincent and Grenadines             Latin America
# 15                        Saint Lucia             Latin America
# 16                            Uruguay             Latin America
# 17                             Panama             Latin America
# 18                           Suriname             Latin America
# 19                               Peru             Latin America
# 20                             Mexico             Latin America
# 21  Venezuela, Bolivarian Republic of             Latin America
# 22                            Ecuador             Latin America
# 23                 Dominican Republic             Latin America
# 24                           Dominica             Latin America
# 25                               Cuba             Latin America
# 26                         Costa Rica             Latin America
# 27                           Colombia             Latin America
# 28                             Brazil             Latin America
# 29                Trinidad and Tobago             Latin America
# 30                           Barbados             Latin America
# 31                            Bahamas             Latin America
# 32                Antigua and Barbuda             Latin America
# 33                            Grenada             Latin America
# 34              Saint Kitts and Nevis             Latin America
# 35                             Turkey  Middle East/Central Asia
# 36                            Lebanon  Middle East/Central Asia
# 37                               Oman  Middle East/Central Asia
# 38                         Kazakhstan  Middle East/Central Asia
# 39                             Jordan  Middle East/Central Asia
# 40          Iran, Islamic Republic of  Middle East/Central Asia
# 41                            Georgia  Middle East/Central Asia
# 42                         Azerbaijan  Middle East/Central Asia
# 43                            Armenia  Middle East/Central Asia
# 44                     Macedonia TFYR   Northern/Eastern Europe
# 45                             Serbia   Northern/Eastern Europe
# 46             Bosnia and Herzegovina   Northern/Eastern Europe
# 47                            Ukraine   Northern/Eastern Europe
# 48                 Russian Federation   Northern/Eastern Europe
# 49                            Albania   Northern/Eastern Europe
#
#     Population (millions)       HDI  GDP per Capita  \
# 0                   38.48  0.730000         5430.57
# 1                   10.88  0.720000         4305.07
# 2                    6.16  0.740000         5859.43
# 3                    1.24  0.770000         8811.15
# 4                    0.88  0.720000         4201.37
# 5                    0.10  0.720000         4330.90
# 6                   21.10  0.750000         2880.03
# 7                   29.24  0.770000        10252.60
# 8                 1408.04  0.720000         5560.94
# 9                    2.80  0.710000         3736.07
# 10                  66.78  0.720000         5479.29
# 11                   7.28  0.780000         7615.28
# 12                  21.76  0.790000         9213.94
# 13                   2.77  0.720000         5226.30
# 14                   0.11  0.720000         6171.48
# 15                   0.18  0.730000         7737.20
# 16                   3.40  0.790000        14238.10
# 17                   3.80  0.770000         8410.77
# 18                   0.54  0.710000         8190.70
# 19                  29.99  0.730000         5684.73
# 20                 120.85  0.750000        10123.90
# 21                  29.96  0.763846        10237.80
# 22                  15.49  0.730000         5192.88
# 23                  10.28  0.710000         6085.89
# 24                   0.07  0.720000         7088.01
# 25                  11.27  0.770000         5175.94
# 26                   4.80  0.760000         8979.96
# 27                  47.70  0.720000         7305.22
# 28                 198.66  0.750000        13237.60
# 29                   1.34  0.770000        18310.80
# 30                   0.28  0.790000        15722.80
# 31                   0.37  0.780000        22647.30
# 32                   0.09  0.780000        13205.10
# 33                   0.10  0.740000         7410.48
# 34                   0.05  0.740000        12952.50
# 35                  74.00  0.760000        10437.70
# 36                   4.65  0.760000         9143.86
# 37                   3.31  0.790000        22622.80
# 38                  16.27  0.780000        11278.00
# 39                   7.01  0.750000         4615.17
# 40                  76.42  0.760000         7511.10
# 41                   4.36  0.750000         3710.70
# 42                   9.31  0.750000         7106.04
# 43                   2.97  0.730000         3426.39
# 44                   2.11  0.740000         5174.89
# 45                   9.55  0.760000         6426.18
# 46                   3.83  0.730000         4708.85
# 47                  45.53  0.740000         3589.63
# 48                 143.17  0.790000        13320.20
# 49                   3.16  0.730000         4534.37
#
#     Total Ecological Footprint  Biocapacity Deficit or Reserve  \
# 0                         2.12                           -1.53
# 1                         2.34                           -1.40
# 2                         3.69                           -3.00
# 3                         3.46                           -2.75
# 4                         2.90                           -0.52
# 5                         2.70                           -1.22
# 6                         1.32                           -0.88
# 7                         3.71                           -1.30
# 8                         3.38                           -2.44
# 9                         6.08                            9.58
# 10                        2.66                           -1.42
# 11                        3.32                           -0.46
# 12                        2.71                           -0.39
# 13                        1.89                           -1.46
# 14                        3.11                           -1.85
# 15                        2.45                           -2.10
# 16                        2.91                            7.41
# 17                        2.79                            0.15
# 18                        4.25                           85.08
# 19                        2.28                            1.69
# 20                        2.89                           -1.62
# 21                        3.57                           -0.79
# 22                        2.17                            0.03
# 23                        1.53                           -0.97
# 24                        2.57                           -1.54
# 25                        1.95                           -1.19
# 26                        2.84                           -1.31
# 27                        1.87                            1.72
# 28                        3.11                            5.97
# 29                        7.92                           -6.36
# 30                        4.48                           -4.29
# 31                        6.84                            2.71
# 32                        5.38                           -4.44
# 33                        2.98                           -1.01
# 34                        4.94                           -4.31
# 35                        3.33                           -1.81
# 36                        3.84                           -3.51
# 37                        7.52                           -5.60
# 38                        5.55                           -2.14
# 39                        2.10                           -1.89
# 40                        2.79                           -1.89
# 41                        1.58                           -0.41
# 42                        2.31                           -1.46
# 43                        2.23                           -1.35
# 44                        3.26                           -1.75
# 45                        2.70                           -1.44
# 46                        3.12                           -1.49
# 47                        2.84                           -0.58
# 48                        5.69                            1.10
# 49                        2.21                           -1.03
#
#     Footprint per Mil Persons
# 0                    0.055094
# 1                    0.215074
# 2                    0.599026
# 3                    2.790323
# 4                    3.295455
# 5                   27.000000
# 6                    0.062559
# 7                    0.126881
# 8                    0.002400
# 9                    2.171429
# 10                   0.039832
# 11                   0.456044
# 12                   0.124540
# 13                   0.682310
# 14                  28.272727
# 15                  13.611111
# 16                   0.855882
# 17                   0.734211
# 18                   7.870370
# 19                   0.076025
# 20                   0.023914
# 21                   0.119159
# 22                   0.140090
# 23                   0.148833
# 24                  36.714286
# 25                   0.173026
# 26                   0.591667
# 27                   0.039203
# 28                   0.015655
# 29                   5.910448
# 30                  16.000000
# 31                  18.486486
# 32                  59.777778
# 33                  29.800000
# 34                  98.800000
# 35                   0.045000
# 36                   0.825806
# 37                   2.271903
# 38                   0.341119
# 39                   0.299572
# 40                   0.036509
# 41                   0.362385
# 42                   0.248120
# 43                   0.750842
# 44                   1.545024
# 45                   0.282723
# 46                   0.814621
# 47                   0.062376
# 48                   0.039743
# 49                   0.699367
